# %% [markdown]
# # Lectura y limpieza dataframes Salario medio CCAA

# %%
# Importar pandas y numpy
import pandas as pd
import numpy as np

# %% [markdown]
# ## Salario medio CCAA Sexo y edad

# %%
df_salario_ccaa_sexo_y_edad = pd.read_excel("databases/salarios/salario_ccaa_sexo_y_edad/28201.xlsx")
df_salario_ccaa_sexo_y_edad
# Out:
# /opt/anaconda3/envs/first_project_ironhack/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      Resultados nacionales y por comunidades aútonomas Unnamed: 1  Unnamed: 2  \
# 0                  Ganancia media anual por trabajador        NaN         NaN
# 1                                                  NaN        NaN         NaN
# 2                                          Sexo y edad        NaN         NaN
# 3                                        Unidades:   €        NaN         NaN
# 4                                                  NaN        NaN         NaN
# ..                                                 ...        ...         ...
# 137  Cuando la casilla está marcada con un signo '-...        NaN         NaN
# 138  '..'=No se facilita el dato correspondiente po...        NaN         NaN
# 139                                                NaN        NaN         NaN
# 140                                           Fuente:         NaN         NaN
# 141                  Instituto Nacional de Estadística        NaN         NaN
#
#      Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0           NaN         NaN         NaN        NaN        NaN        NaN
# 1           NaN         NaN         NaN        NaN        NaN        NaN
# 2           NaN         NaN         NaN        NaN        NaN        NaN
# 3           NaN         NaN         NaN        NaN        NaN        NaN
# 4           NaN         NaN         NaN        NaN        NaN        NaN
# ..          ...         ...         ...        ...        ...        ...
# 137         NaN         NaN         NaN        NaN        NaN        NaN
# 138         NaN         NaN         NaN        NaN        NaN        NaN
# 139         NaN         NaN         NaN        NaN        NaN        NaN
# 140         NaN         NaN         NaN        NaN        NaN        NaN
# 141         NaN         NaN         NaN        NaN        NaN        NaN
#
#     Unnamed: 9 Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0          NaN         NaN          NaN          NaN          NaN          NaN
# 1          NaN         NaN          NaN          NaN          NaN          NaN
# 2          NaN         NaN          NaN          NaN          NaN          NaN
# 3          NaN         NaN          NaN          NaN          NaN          NaN
# 4          NaN         NaN          NaN          NaN          NaN          NaN
# ..         ...         ...          ...          ...          ...          ...
# 137        NaN         NaN          NaN          NaN          NaN          NaN
# 138        NaN         NaN          NaN          NaN          NaN          NaN
# 139        NaN         NaN          NaN          NaN          NaN          NaN
# 140        NaN         NaN          NaN          NaN          NaN          NaN
# 141        NaN         NaN          NaN          NaN          NaN          NaN
#
# [142 rows x 15 columns]

# %%
df_salario_ccaa_sexo_y_edad.dtypes
# Out:
# Resultados nacionales y por comunidades aútonomas     object
# Unnamed: 1                                            object
# Unnamed: 2                                           float64
# Unnamed: 3                                           float64
# Unnamed: 4                                           float64
# Unnamed: 5                                           float64
# Unnamed: 6                                            object
# Unnamed: 7                                            object
# Unnamed: 8                                            object
# Unnamed: 9                                            object
# Unnamed: 10                                           object
# Unnamed: 11                                          float64
# Unnamed: 12                                          float64
# Unnamed: 13                                          float64
# Unnamed: 14                                          float64
# dtype: object

# %%
df_salario_ccaa_sexo_y_edad = pd.read_excel("/Users/adrianbenitezrueda/Documents/IRONHACK/GITHUB/WEEK 3/FIRST PROJECT/first-project-data/databases/salarios/salario_ccaa_sexo_y_edad/28201.xlsx", skiprows=7)
# Out:
# /opt/anaconda3/envs/first_project_ironhack/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 29   20776   21322   21395   21478   22036  22801.0  23325.0  23881.0  24135.0
# 30  -11286  -14645  -13339  -12572  -13966 -15256.0 -13985.0 -14541.0 -14471.0
# 31   17165   18343   17104   16341   17787  18759.0  20076.0  19414.0  20381.0
# 32   21311   22441   21306   21794   22385  22849.0  23626.0  23805.0  23607.0
# 33   23015   23196   24772   24362   24452  26124.0  25674.0  26009.0  26167.0
# 34   22715   22521   23837   24833   24425  25708.0  26110.0  26908.0  26875.0
# 35     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 36   19168   19436   19857   19749   20185  20763.0  20861.0  21631.0  22466.0
# 37   -9149  -11431  -11978  -11432  -12609 -12182.0 -11319.0 -11499.0 -11615.0
# 38   14588   15419   14969   15009   15295  16989.0  16468.0  16609.0  16478.0
# 39   19249   19131   20029   19227   19698  20814.0  20495.0  20923.0  21674.0
# 40   22128   22395   22148   21965   22336  23122.0  23737.0  24056.0  24722.0
# 41   22307   23981   23186   23238   23573  23593.0  24158.0  25190.0  26225.0
# 42     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN
# 43   20052   21200   21857   22063   22390  22555.0  23348.0  23495.0  24471.0
# 44  -10289      ..      ..      ..      .. -12764.0 -12532.0 -12940.0 -12156.0
# 45   16718   17171   16778   16471   16587  18289.0  19686.0  19736.0  20502.0
# 46   20037   21581   20930   21260   22287  22550.0  23088.0  23422.0  23885.0
# 47   22031   24173   24611   24137   23631  24351.0  24647.0  25069.0  26383.0
# 48   22084   22151   24617   25665   26314  25063.0  26047.0  24995.0  26317.0
# 49     NaN     NaN     NaN     NaN     NaN      NaN      NaN      NaN      NaN

# %%
# Crear una lista con todas las localizaciones (las que estaban en tu diccionario)
localizaciones = [
    "Total Nacional", "Andalucía", "Aragón", "Asturias, Principado de", "Balears, Illes", "Canarias", 
    "Cantabria", "Castilla y León", "Castilla - La Mancha", "Cataluña", "Comunitat Valenciana", 
    "Extremadura", "Galicia", "Madrid, Comunidad de", "Murcia, Región de", "Navarra, Comunidad Foral de", "País Vasco", "Rioja, La"
]

# Crear una lista con los rangos de edad
edades = ["Todas las edades", "Menos de 25 años", "De 25 a 34 años", "De 35 a 44 años", "De 45 a 54 años", "55 y más años"]

# Crear dos nuevas columnas: una para 'Localización' y otra para 'Rango de edad'
# Procesamos primero las localizaciones
df_salario_ccaa_sexo_y_edad['Localización'] = df_salario_ccaa_sexo_y_edad.iloc[:, 0].apply(lambda x: x if x in localizaciones else None)

# Rellenar las celdas de Localización hacia adelante (hacia abajo)
df_salario_ccaa_sexo_y_edad['Localización'].fillna(method='ffill', inplace=True)

# Luego procesamos los rangos de edad, ignorando las localizaciones ya procesadas
df_salario_ccaa_sexo_y_edad['Rango de edad'] = df_salario_ccaa_sexo_y_edad.iloc[:, 0].apply(lambda x: x if x in edades else None)

# Ahora podemos eliminar la primera columna y crear el MultiIndex
df_salario_ccaa_sexo_y_edad.drop(df_salario_ccaa_sexo_y_edad.columns[0], axis=1, inplace=True)

# Aplicar el MultiIndex con las nuevas columnas 'Localización' y 'Rango de edad'
df_salario_ccaa_sexo_y_edad = df_salario_ccaa_sexo_y_edad.set_index(['Localización', 'Rango de edad'])

# El dataframe ahora tendrá un MultiIndex adecuado
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/511411944.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_salario_ccaa_sexo_y_edad['Localización'].fillna(method='ffill', inplace=True)
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/511411944.py:16: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_salario_ccaa_sexo_y_edad['Localización'].fillna(method='ffill', inplace=True)

# %%
df_salario_ccaa_sexo_y_edad.head(10)
# Out:
#                                  2008     2009     2010     2011     2012  \
# Localización   Rango de edad
# Total Nacional NaN                NaN      NaN      NaN      NaN      NaN
#                NaN            21883.0  22511.0  22790.0  22899.0  22726.0
#                NaN            12954.0  12566.0  13155.0  11955.0  11077.0
#                NaN            19206.0  19476.0  19772.0  19269.0  18690.0
#                NaN            22977.0  23300.0  23732.0  23830.0  23520.0
#                NaN            25016.0  25447.0  25819.0  25835.0  25259.0
#                NaN            25235.0  25281.0  26162.0  26124.0  25373.0
# Andalucía      NaN                NaN      NaN      NaN      NaN      NaN
#                NaN            20139.0  20906.0  20964.0  21351.0  20892.0
#                NaN            12600.0  11955.0  11618.0  11060.0  10544.0
#
#                                2013    2014    2015    2016    2017     2018  \
# Localización   Rango de edad
# Total Nacional NaN              NaN     NaN     NaN     NaN     NaN      NaN
#                NaN            22698   22858   23106   23156   23646  24009.0
#                NaN            10506   11560   11040   11046   11473  12418.0
#                NaN            17973   18680   18252   17978   18506  19350.0
#                NaN            23232   23504   23336   23300   23690  24381.0
#                NaN            25229   25421   25475   25499   25950  26417.0
#                NaN            25632   26137   26327   26203   26646  27151.0
# Andalucía      NaN              NaN     NaN     NaN     NaN     NaN      NaN
#                NaN            20782   20840   21381   21268   21404  21806.0
#                NaN            -9672  -10003  -10114  -10237  -11077  11236.0
#
#                                  2019     2020     2021
# Localización   Rango de edad
# Total Nacional NaN                NaN      NaN      NaN
#                NaN            24396.0  25166.0  25897.0
#                NaN            12270.0  12694.0  12930.0
#                NaN            19563.0  20091.0  20848.0
#                NaN            24631.0  25039.0  25615.0
#                NaN            26886.0  27500.0  28220.0
#                NaN            27540.0  28124.0  28687.0
# Andalucía      NaN                NaN      NaN      NaN
#                NaN            22061.0  22324.0  23155.0
#                NaN            11639.0 -11314.0  12590.0

# %%
# Lista de reemplazo
edades = [np.nan, "Todas las edades", "Menos de 25 años", "De 25 a 34 años", "De 35 a 44 años", "De 45 a 54 años", "55 y más años"]

# Crear una columna temporal con el índice cíclico
df_salario_ccaa_sexo_y_edad.reset_index(inplace=True)  # Convertir MultiIndex a columnas normales
cycle_length = len(edades)
replacement_indices = np.arange(len(df_salario_ccaa_sexo_y_edad)) % cycle_length
df_salario_ccaa_sexo_y_edad['Replacement Index'] = replacement_indices

# Reemplazar los valores en la columna 'Rango de edad'
df_salario_ccaa_sexo_y_edad['Rango de edad'] = df_salario_ccaa_sexo_y_edad['Replacement Index'].map(lambda x: edades[x])

# Volver a establecer el MultiIndex
df_salario_ccaa_sexo_y_edad.set_index(['Localización', 'Rango de edad'], inplace=True)  # Cambia 'level_0' por el primer nivel original del índice

# Eliminar la columna temporal
df_salario_ccaa_sexo_y_edad.drop(columns=['Replacement Index'], inplace=True)

df_salario_ccaa_sexo_y_edad
# Out:
#                                     2008     2009     2010     2011     2012  \
# Localización   Rango de edad
# Total Nacional NaN                   NaN      NaN      NaN      NaN      NaN
#                Todas las edades  21883.0  22511.0  22790.0  22899.0  22726.0
#                Menos de 25 años  12954.0  12566.0  13155.0  11955.0  11077.0
#                De 25 a 34 años   19206.0  19476.0  19772.0  19269.0  18690.0
#                De 35 a 44 años   22977.0  23300.0  23732.0  23830.0  23520.0
# ...                                  ...      ...      ...      ...      ...
# Rioja, La      De 35 a 44 años       NaN      NaN      NaN      NaN      NaN
#                De 45 a 54 años       NaN      NaN      NaN      NaN      NaN
#                55 y más años         NaN      NaN      NaN      NaN      NaN
#                NaN                   NaN      NaN      NaN      NaN      NaN
#                Todas las edades      NaN      NaN      NaN      NaN      NaN
#
#                                   2013   2014   2015   2016   2017     2018  \
# Localización   Rango de edad
# Total Nacional NaN                 NaN    NaN    NaN    NaN    NaN      NaN
#                Todas las edades  22698  22858  23106  23156  23646  24009.0
#                Menos de 25 años  10506  11560  11040  11046  11473  12418.0
#                De 25 a 34 años   17973  18680  18252  17978  18506  19350.0
#                De 35 a 44 años   23232  23504  23336  23300  23690  24381.0
# ...                                ...    ...    ...    ...    ...      ...
# Rioja, La      De 35 a 44 años     NaN    NaN    NaN    NaN    NaN      NaN
#                De 45 a 54 años     NaN    NaN    NaN    NaN    NaN      NaN
#                55 y más años       NaN    NaN    NaN    NaN    NaN      NaN
#                NaN                 NaN    NaN    NaN    NaN    NaN      NaN
#                Todas las edades    NaN    NaN    NaN    NaN    NaN      NaN
#
#                                     2019     2020     2021
# Localización   Rango de edad
# Total Nacional NaN                   NaN      NaN      NaN
#                Todas las edades  24396.0  25166.0  25897.0
#                Menos de 25 años  12270.0  12694.0  12930.0
#                De 25 a 34 años   19563.0  20091.0  20848.0
#                De 35 a 44 años   24631.0  25039.0  25615.0
# ...                                  ...      ...      ...
# Rioja, La      De 35 a 44 años       NaN      NaN      NaN
#                De 45 a 54 años       NaN      NaN      NaN
#                55 y más años         NaN      NaN      NaN
#                NaN                   NaN      NaN      NaN
#                Todas las edades      NaN      NaN      NaN
#
# [135 rows x 14 columns]

# %%
df_salario_ccaa_sexo_y_edad = df_salario_ccaa_sexo_y_edad.iloc[:-9]

# %%
df_salario_ccaa_sexo_y_edad
# Out:
#                                     2008     2009     2010     2011     2012  \
# Localización   Rango de edad
# Total Nacional NaN                   NaN      NaN      NaN      NaN      NaN
#                Todas las edades  21883.0  22511.0  22790.0  22899.0  22726.0
#                Menos de 25 años  12954.0  12566.0  13155.0  11955.0  11077.0
#                De 25 a 34 años   19206.0  19476.0  19772.0  19269.0  18690.0
#                De 35 a 44 años   22977.0  23300.0  23732.0  23830.0  23520.0
# ...                                  ...      ...      ...      ...      ...
# Rioja, La      Menos de 25 años -13303.0 -13419.0 -12807.0 -13596.0 -10997.0
#                De 25 a 34 años   18655.0  18741.0  19273.0  17257.0  16494.0
#                De 35 a 44 años   20595.0  21244.0  21074.0  20585.0  20285.0
#                De 45 a 54 años   23998.0  24134.0  23002.0  24828.0  23804.0
#                55 y más años     22815.0  22643.0 -25267.0  25501.0  23494.0
#
#                                   2013    2014    2015   2016   2017     2018  \
# Localización   Rango de edad
# Total Nacional NaN                 NaN     NaN     NaN    NaN    NaN      NaN
#                Todas las edades  22698   22858   23106  23156  23646  24009.0
#                Menos de 25 años  10506   11560   11040  11046  11473  12418.0
#                De 25 a 34 años   17973   18680   18252  17978  18506  19350.0
#                De 35 a 44 años   23232   23504   23336  23300  23690  24381.0
# ...                                ...     ...     ...    ...    ...      ...
# Rioja, La      Menos de 25 años     ..  -12045  -10929  -9784  -8957 -12075.0
#                De 25 a 34 años   15864   18521   17674  17561  18041  18853.0
#                De 35 a 44 años   20909   22049   21744  22070  22593  22837.0
#                De 45 a 54 años   23252   23715   23987  24751  24416  24350.0
#                55 y más años     23333   25604   24731  24151  24148  25014.0
#
#                                     2019     2020     2021
# Localización   Rango de edad
# Total Nacional NaN                   NaN      NaN      NaN
#                Todas las edades  24396.0  25166.0  25897.0
#                Menos de 25 años  12270.0  12694.0  12930.0
#                De 25 a 34 años   19563.0  20091.0  20848.0
#                De 35 a 44 años   24631.0  25039.0  25615.0
# ...                                  ...      ...      ...
# Rioja, La      Menos de 25 años -11525.0 -13440.0 -13970.0
#                De 25 a 34 años   18495.0  18788.0  19108.0
#                De 35 a 44 años   22648.0  22838.0  23289.0
#                De 45 a 54 años   25777.0  25915.0  26338.0
#                55 y más años     24631.0  24465.0  25047.0
#
# [126 rows x 14 columns]

# %%
df_salario_ccaa_sexo_y_edad.isnull().sum()
# Out:
# 2008    18
# 2009    18
# 2010    18
# 2011    18
# 2012    18
# 2013    18
# 2014    18
# 2015    18
# 2016    18
# 2017    18
# 2018    18
# 2019    18
# 2020    18
# 2021    18
# dtype: int64

# %%
df_salario_ccaa_sexo_y_edad.dropna(inplace=True)
df_salario_ccaa_sexo_y_edad
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/892102226.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salario_ccaa_sexo_y_edad.dropna(inplace=True)
#                                     2008     2009     2010     2011     2012  \
# Localización   Rango de edad
# Total Nacional Todas las edades  21883.0  22511.0  22790.0  22899.0  22726.0
#                Menos de 25 años  12954.0  12566.0  13155.0  11955.0  11077.0
#                De 25 a 34 años   19206.0  19476.0  19772.0  19269.0  18690.0
#                De 35 a 44 años   22977.0  23300.0  23732.0  23830.0  23520.0
#                De 45 a 54 años   25016.0  25447.0  25819.0  25835.0  25259.0
# ...                                  ...      ...      ...      ...      ...
# Rioja, La      Menos de 25 años -13303.0 -13419.0 -12807.0 -13596.0 -10997.0
#                De 25 a 34 años   18655.0  18741.0  19273.0  17257.0  16494.0
#                De 35 a 44 años   20595.0  21244.0  21074.0  20585.0  20285.0
#                De 45 a 54 años   23998.0  24134.0  23002.0  24828.0  23804.0
#                55 y más años     22815.0  22643.0 -25267.0  25501.0  23494.0
#
#                                   2013    2014    2015   2016   2017     2018  \
# Localización   Rango de edad
# Total Nacional Todas las edades  22698   22858   23106  23156  23646  24009.0
#                Menos de 25 años  10506   11560   11040  11046  11473  12418.0
#                De 25 a 34 años   17973   18680   18252  17978  18506  19350.0
#                De 35 a 44 años   23232   23504   23336  23300  23690  24381.0
#                De 45 a 54 años   25229   25421   25475  25499  25950  26417.0
# ...                                ...     ...     ...    ...    ...      ...
# Rioja, La      Menos de 25 años     ..  -12045  -10929  -9784  -8957 -12075.0
#                De 25 a 34 años   15864   18521   17674  17561  18041  18853.0
#                De 35 a 44 años   20909   22049   21744  22070  22593  22837.0
#                De 45 a 54 años   23252   23715   23987  24751  24416  24350.0
#                55 y más años     23333   25604   24731  24151  24148  25014.0
#
#                                     2019     2020     2021
# Localización   Rango de edad
# Total Nacional Todas las edades  24396.0  25166.0  25897.0
#                Menos de 25 años  12270.0  12694.0  12930.0
#                De 25 a 34 años   19563.0  20091.0  20848.0
#                De 35 a 44 años   24631.0  25039.0  25615.0
#                De 45 a 54 años   26886.0  27500.0  28220.0
# ...                                  ...      ...      ...
# Rioja, La      Menos de 25 años -11525.0 -13440.0 -13970.0
#                De 25 a 34 años   18495.0  18788.0  19108.0
#                De 35 a 44 años   22648.0  22838.0  23289.0
#                De 45 a 54 años   25777.0  25915.0  26338.0
#                55 y más años     24631.0  24465.0  25047.0
#
# [108 rows x 14 columns]

# %%
df_salario_ccaa_sexo_y_edad.isnull().sum()
# Out:
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %%
# Multiplica por -1 todos los valores negativos en el DataFrame
df_salario_ccaa_sexo_y_edad = df_salario_ccaa_sexo_y_edad.applymap(lambda x: -x if isinstance(x, (int, float)) and x < 0 else x)

df_salario_ccaa_sexo_y_edad.head(40)
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/2871923794.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_salario_ccaa_sexo_y_edad = df_salario_ccaa_sexo_y_edad.applymap(lambda x: -x if isinstance(x, (int, float)) and x < 0 else x)
#                                              2008     2009     2010     2011  \
# Localización            Rango de edad
# Total Nacional          Todas las edades  21883.0  22511.0  22790.0  22899.0
#                         Menos de 25 años  12954.0  12566.0  13155.0  11955.0
#                         De 25 a 34 años   19206.0  19476.0  19772.0  19269.0
#                         De 35 a 44 años   22977.0  23300.0  23732.0  23830.0
#                         De 45 a 54 años   25016.0  25447.0  25819.0  25835.0
#                         55 y más años     25235.0  25281.0  26162.0  26124.0
# Andalucía               Todas las edades  20139.0  20906.0  20964.0  21351.0
#                         Menos de 25 años  12600.0  11955.0  11618.0  11060.0
#                         De 25 a 34 años   17462.0  17344.0  17300.0  16970.0
#                         De 35 a 44 años   20949.0  21468.0  21617.0  21693.0
#                         De 45 a 54 años   24046.0  25030.0  24762.0  25184.0
#                         55 y más años     23454.0  24553.0  27066.0  27154.0
#                         55 y más años     24425  25708.0  26110.0  26908.0
# Canarias                Todas las edades  20185  20763.0  20861.0  21631.0
#                         Menos de 25 años  12609  12182.0  11319.0  11499.0
#                         De 25 a 34 años   15295  16989.0  16468.0  16609.0
#                         De 35 a 44 años   19698  20814.0  20495.0  20923.0
#                         De 45 a 54 años   22336  23122.0  23737.0  24056.0
#                         55 y más años     23573  23593.0  24158.0  25190.0
# Cantabria               Todas las edades  22390  22555.0  23348.0  23495.0
#                         Menos de 25 años     ..  12764.0  12532.0  12940.0
#                         De 25 a 34 años   16587  18289.0  19686.0  19736.0
#                         De 35 a 44 años   22287  22550.0  23088.0  23422.0
#
#                                              2021
# Localización            Rango de edad
# Total Nacional          Todas las edades  25897.0
#                         Menos de 25 años  12930.0
#                         De 25 a 34 años   20848.0
#                         De 35 a 44 años   25615.0
#                         De 45 a 54 años   28220.0
#                         55 y más años     28687.0
# Andalucía               Todas las edades  23155.0
#                         Menos de 25 años  12590.0
#                         De 25 a 34 años   17631.0
#                         De 35 a 44 años   21964.0
#                         De 45 a 54 años   25423.0
#                         55 y más años     27410.0
# Aragón                  Todas las edades  25012.0
#                         Menos de 25 años  13898.0
#                         De 25 a 34 años   19605.0
#                         De 35 a 44 años   25194.0
#                         De 45 a 54 años   26733.0
#                         55 y más años     26904.0
# Asturias, Principado de Todas las edades  25047.0
#                         Menos de 25 años  13307.0
#                         De 25 a 34 años   18571.0
#                         De 35 a 44 años   24195.0
#                         De 45 a 54 años   26754.0
#                         55 y más años     28097.0
# Balears, Illes          Todas las edades  24135.0
#                         Menos de 25 años  14471.0
#                         De 25 a 34 años   20381.0
#                         De 35 a 44 años   23607.0
#                         De 45 a 54 años   26167.0
#                         55 y más años     26875.0
# Canarias                Todas las edades  22466.0
#                         Menos de 25 años  11615.0
#                         De 25 a 34 años   16478.0
#                         De 35 a 44 años   21674.0
#                         De 45 a 54 años   24722.0
#                         55 y más años     26225.0
# Cantabria               Todas las edades  24471.0
#                         Menos de 25 años  12156.0
#                         De 25 a 34 años   20502.0
#                         De 35 a 44 años   23885.0

# %%
# Definir la función para calcular el reemplazo de los salarios inexistentes a partir de la variación de todas las edades del mismo año y el anterior por el año anterior en ese rango de edad
def calcular_reemplazo_correcto(df, fila, columna):
    # Identificamos la comunidad autónoma
    ccaa = df.index[fila][0]  # Extraemos "Localización" desde el MultiIndex (primer nivel del índice)

    # Buscamos el valor del mismo año y el año anterior, pero para el rango "Todas las edades" y misma CCAA
    fila_todas_edades = df.loc[(ccaa, 'Todas las edades')]

    # Verificamos que los valores del año actual y el año anterior sean numéricos
    if not fila_todas_edades.empty:
        try:
            valor_anterior_todas_edades = fila_todas_edades.iloc[columna - 1]  # Valor de la columna anterior (año anterior)
            valor_actual_todas_edades = fila_todas_edades.iloc[columna]  # Valor en la columna actual (año actual)

            # Calcular la variación porcentual entre los valores del salario (solo si ambos son numéricos)
            if isinstance(valor_anterior_todas_edades, (int, float)) and isinstance(valor_actual_todas_edades, (int, float)):
                variacion = (valor_actual_todas_edades - valor_anterior_todas_edades) / valor_anterior_todas_edades
            else:
                return df.iloc[fila, columna]  # Devolvemos el valor original si no son numéricos

        except IndexError:
            return df.iloc[fila, columna]  # Devolvemos el valor original si ocurre un error de índice

        # Obtener el valor del año anterior en el mismo rango de edad y comunidad autónoma
        valor_anterior = df.iloc[fila, columna - 1]  # Valor de la columna a la izquierda para ese rango de edad

        # Si el valor anterior es numérico, realizamos el cálculo, limitamos el resultado a 1 decimal y lo retornamos
        if isinstance(valor_anterior, (int, float)):
            return round(valor_anterior * (1 + variacion), 1)

    # Si no se pudo calcular, devolvemos el valor original (posiblemente NaN)
    return df.iloc[fila, columna]

# Aplicamos la fórmula de reemplazo en todas las celdas que contienen valores no numéricos (como '..')
for fila in range(len(df_salario_ccaa_sexo_y_edad)):
    for columna in range(2, len(df_salario_ccaa_sexo_y_edad.columns)):  # Las columnas de años empiezan en la posición 2
        if isinstance(df_salario_ccaa_sexo_y_edad.iloc[fila, columna], str):  # Revisamos si el valor es string (valor no numérico)
            df_salario_ccaa_sexo_y_edad.iloc[fila, columna] = calcular_reemplazo_correcto(df_salario_ccaa_sexo_y_edad, fila, columna)

# Mostrar el DataFrame resultante
df_salario_ccaa_sexo_y_edad
# Out:
#                                     2008     2009     2010     2011     2012  \
# Localización   Rango de edad
# Total Nacional Todas las edades  21883.0  22511.0  22790.0  22899.0  22726.0
#                Menos de 25 años  12954.0  12566.0  13155.0  11955.0  11077.0
#                De 25 a 34 años   19206.0  19476.0  19772.0  19269.0  18690.0
#                De 35 a 44 años   22977.0  23300.0  23732.0  23830.0  23520.0
#                De 45 a 54 años   25016.0  25447.0  25819.0  25835.0  25259.0
# ...                                  ...      ...      ...      ...      ...
# Rioja, La      Menos de 25 años  13303.0  13419.0  12807.0  13596.0  10997.0
#                De 25 a 34 años   18655.0  18741.0  19273.0  17257.0  16494.0
#                De 35 a 44 años   20595.0  21244.0  21074.0  20585.0  20285.0
#                De 45 a 54 años   23998.0  24134.0  23002.0  24828.0  23804.0
#                55 y más años     22815.0  22643.0  25267.0  25501.0  23494.0
#
#                                     2013   2014   2015   2016   2017     2018  \
# Localización   Rango de edad
# Total Nacional Todas las edades    22698  22858  23106  23156  23646  24009.0
#                Menos de 25 años    10506  11560  11040  11046  11473  12418.0
#                De 25 a 34 años     17973  18680  18252  17978  18506  19350.0
#                De 35 a 44 años     23232  23504  23336  23300  23690  24381.0
#                De 45 a 54 años     25229  25421  25475  25499  25950  26417.0
# ...                                  ...    ...    ...    ...    ...      ...
# Rioja, La      Menos de 25 años  11150.0  12045  10929   9784   8957  12075.0
#                De 25 a 34 años     15864  18521  17674  17561  18041  18853.0
#                De 35 a 44 años     20909  22049  21744  22070  22593  22837.0
#                De 45 a 54 años     23252  23715  23987  24751  24416  24350.0
#                55 y más años       23333  25604  24731  24151  24148  25014.0
#
#                                     2019     2020     2021
# Localización   Rango de edad
# Total Nacional Todas las edades  24396.0  25166.0  25897.0
#                Menos de 25 años  12270.0  12694.0  12930.0
NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 36  20441.0  20525.0  21296.0  21552.0  21847.0  22035.0  22061.0  22949.0
# 37  24530.0  25306.0  25227.0  25730.0  26457.0  27612.0  27112.0  27149.0
# 38  20691.0  20046.0  20550.0  20536.0  21815.0  21657.0  21575.0  22728.0
# 39  19307.0  19311.0  20280.0  20481.0  20591.0  20569.0  20783.0  21867.0
#
#        2021
# 0       NaN
# 1   25897.0
# 2   29104.0
# 3   24137.0
# 4   25449.0
# 5       NaN
# 6   23155.0
# 7   26090.0
# 8   22212.0
# 9   22843.0
# 10      NaN
# 11  25012.0
# 12  27698.0
# 13  26310.0
# 14  24062.0
# 15      NaN
# 16  25047.0
# 17  32084.0
# 18  26171.0
# 19  23394.0
# 20      NaN
# 21  24135.0
# 22  25105.0
# 23  23360.0
# 24  24157.0
# 25      NaN
# 26  22466.0
# 27  23869.0
# 28  19937.0
# 29  22565.0
# 30      NaN
# 31  24471.0
# 32  29757.0
# 33 -23401.0
# 34  23343.0
# 35      NaN
# 36  23564.0
# 37  27801.0
# 38  22933.0
# 39  22497.0

# %%
# Crear una lista con todas las localizaciones (las que estaban en tu diccionario)
localizaciones = [
    "Total Nacional", "Andalucía", "Aragón", "Asturias, Principado de", "Balears, Illes", "Canarias", 
    "Cantabria", "Castilla y León", "Castilla - La Mancha", "Cataluña", "Comunitat Valenciana", 
    "Extremadura", "Galicia", "Madrid, Comunidad de", "Murcia, Región de", "Navarra, Comunidad Foral de", "País Vasco", "Rioja, La"
]

# Crear una lista con los sectores
sectores = ["Todos los sectores", "Industria", "Construcción", "Servicios"]

# Crear dos nuevas columnas: una para 'Localización' y otra para 'Sector'
# Procesamos primero las localizaciones
df_salario_ccaa_sexo_y_sectoractividad['Localización'] = df_salario_ccaa_sexo_y_sectoractividad.iloc[:, 0].apply(lambda x: x if x in localizaciones else None)

# Rellenar las celdas de Localización hacia adelante (hacia abajo)
df_salario_ccaa_sexo_y_sectoractividad['Localización'].fillna(method='ffill', inplace=True)

# Luego procesamos los sectores, ignorando las localizaciones ya procesadas
df_salario_ccaa_sexo_y_sectoractividad['Sector'] = df_salario_ccaa_sexo_y_sectoractividad.iloc[:, 0].apply(lambda x: x if x in edades else None)

# Ahora podemos eliminar la primera columna y crear el MultiIndex
df_salario_ccaa_sexo_y_sectoractividad.drop(df_salario_ccaa_sexo_y_sectoractividad.columns[0], axis=1, inplace=True)

# Aplicar el MultiIndex con las nuevas columnas 'Localización' y 'Sector'
df_salario_ccaa_sexo_y_sectoractividad = df_salario_ccaa_sexo_y_sectoractividad.set_index(['Localización', 'Sector'])

# El dataframe ahora tendrá un MultiIndex adecuado
df_salario_ccaa_sexo_y_sectoractividad
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/272185978.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_salario_ccaa_sexo_y_sectoractividad['Localización'].fillna(method='ffill', inplace=True)
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/272185978.py:16: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_salario_ccaa_sexo_y_sectoractividad['Localización'].fillna(method='ffill', inplace=True)
#                           2008     2009     2010     2011     2012     2013  \
# Localización   Sector
# Total Nacional NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN     21883.0  22511.0  22790.0  22899.0  22726.0  22698.0
#                NaN     24036.0  24453.0  25377.0  25872.0  26122.0  26639.0
#                NaN     20707.0  21775.0  21962.0  22541.0  22686.0  22721.0
#                NaN     21557.0  22171.0  22332.0  22315.0  22040.0  21920.0
# ...                        ...      ...      ...      ...      ...      ...
# Rioja, La      NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#
#                           2014     2015     2016     2017     2018     2019  \
# Localización   Sector
# Total Nacional NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN     22858.0  23106.0  23156.0  23646.0  24009.0  24396.0
#                NaN     26997.0  27104.0  27198.0  27708.0  28097.0  28074.0
#                NaN     22608.0  22661.0  22163.0  22608.0  22971.0  22789.0
#                NaN     22077.0  22367.0  22440.0  22944.0  23326.0  23845.0
# ...                        ...      ...      ...      ...      ...      ...
# Rioja, La      NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#                NaN         NaN      NaN      NaN      NaN      NaN      NaN
#
#                           2020     2021
# Localización   Sector
# Total Nacional NaN         NaN      NaN
#                NaN     25166.0  25897.0
#                NaN     28375.0  29104.0
#                NaN     23105.0  24137.0
#                NaN     24731.0  25449.0
# ...                        ...      ...
# Rioja, La      NaN         NaN      NaN
#                NaN         NaN      NaN
#                NaN         NaN      NaN
#                NaN         NaN      NaN
#                NaN         NaN      NaN
#
# [98 rows x 14 columns]

# %%
# Lista de reemplazo
sectores = [np.nan, "Todos los sectores", "Industria", "Construcción", "Servicios"]

# Crear una columna temporal con el índice cíclico
df_salario_ccaa_sexo_y_sectoractividad.reset_index(inplace=True)  # Convertir MultiIndex a columnas normales
cycle_length = len(sectores)
replacement_indices = np.arange(len(df_salario_ccaa_sexo_y_sectoractividad)) % cycle_length
df_salario_ccaa_sexo_y_sectoractividad['Replacement Index'] = replacement_indices

# Reemplazar los valores en la columna 'Sector'
df_salario_ccaa_sexo_y_sectoractividad['Sector'] = df_salario_ccaa_sexo_y_sectoractividad['Replacement Index'].map(lambda x: sectores[x])

# Volver a establecer el MultiIndex
df_salario_ccaa_sexo_y_sectoractividad.set_index(['Localización', 'Sector'], inplace=True)  # Cambia 'level_0' por el primer nivel original del índice

# Eliminar la columna temporal
df_salario_ccaa_sexo_y_sectoractividad.drop(columns=['Replacement Index'], inplace=True)

df_salario_ccaa_sexo_y_sectoractividad
# Out:
#                                       2008     2009     2010     2011  \
# Localización   Sector
# Total Nacional NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  21883.0  22511.0  22790.0  22899.0
#                Industria           24036.0  24453.0  25377.0  25872.0
#                Construcción        20707.0  21775.0  21962.0  22541.0
#                Servicios           21557.0  22171.0  22332.0  22315.0
# ...                                    ...      ...      ...      ...
# Rioja, La      Construcción            NaN      NaN      NaN      NaN
#                Servicios               NaN      NaN      NaN      NaN
#                NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores      NaN      NaN      NaN      NaN
#                Industria               NaN      NaN      NaN      NaN
#
#                                       2012     2013     2014     2015  \
# Localización   Sector
# Total Nacional NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  22726.0  22698.0  22858.0  23106.0
#                Industria           26122.0  26639.0  26997.0  27104.0
#                Construcción        22686.0  22721.0  22608.0  22661.0
#                Servicios           22040.0  21920.0  22077.0  22367.0
# ...                                    ...      ...      ...      ...
# Rioja, La      Construcción            NaN      NaN      NaN      NaN
#                Servicios               NaN      NaN      NaN      NaN
#                NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores      NaN      NaN      NaN      NaN
#                Industria               NaN      NaN      NaN      NaN
#
#                                       2016     2017     2018     2019  \
# Localización   Sector
# Total Nacional NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  23156.0  23646.0  24009.0  24396.0
#                Industria           27198.0  27708.0  28097.0  28074.0
#                Construcción        22163.0  22608.0  22971.0  22789.0
#                Servicios           22440.0  22944.0  23326.0  23845.0
# ...                                    ...      ...      ...      ...
# Rioja, La      Construcción            NaN      NaN      NaN      NaN
#                Servicios               NaN      NaN      NaN      NaN
#                NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores      NaN      NaN      NaN      NaN
#                Industria               NaN      NaN      NaN      NaN
#
#                                       2020     2021
# Localización   Sector
# Total Nacional NaN                     NaN      NaN
#                Todos los sectores  25166.0  25897.0
#                Industria           28375.0  29104.0
#                Construcción        23105.0  24137.0
#                Servicios           24731.0  25449.0
# ...                                    ...      ...
# Rioja, La      Construcción            NaN      NaN
#                Servicios               NaN      NaN
#                NaN                     NaN      NaN
#                Todos los sectores      NaN      NaN
#                Industria               NaN      NaN
#
# [98 rows x 14 columns]

# %%
#Eliminar las últimas filas con NaN
df_salario_ccaa_sexo_y_sectoractividad = df_salario_ccaa_sexo_y_sectoractividad.iloc[:-8]
df_salario_ccaa_sexo_y_sectoractividad
# Out:
#                                       2008     2009     2010     2011  \
# Localización   Sector
# Total Nacional NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  21883.0  22511.0  22790.0  22899.0
#                Industria           24036.0  24453.0  25377.0  25872.0
#                Construcción        20707.0  21775.0  21962.0  22541.0
#                Servicios           21557.0  22171.0  22332.0  22315.0
# ...                                    ...      ...      ...      ...
# Rioja, La      NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  20674.0  21180.0  21036.0  20997.0
#                Industria           21660.0  21512.0  21783.0  22563.0
#                Construcción        20506.0 -22006.0 -22762.0 -23519.0
#                Servicios           20215.0  20887.0  20436.0  19995.0
#
#                                       2012     2013     2014     2015  \
# Localización   Sector
# Total Nacional NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  22726.0  22698.0  22858.0  23106.0
#                Industria           26122.0  26639.0  26997.0  27104.0
#                Construcción        22686.0  22721.0  22608.0  22661.0
#                Servicios           22040.0  21920.0  22077.0  22367.0
# ...                                    ...      ...      ...      ...
# Rioja, La      NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  20346.0  20629.0  21954.0  21757.0
#                Industria           22721.0  22387.0  23792.0  23862.0
#                Construcción       -22767.0 -22506.0 -22984.0 -23416.0
#                Servicios           19126.0  19759.0  21116.0  20730.0
#
#                                       2016     2017     2018     2019  \
# Localización   Sector
# Total Nacional NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  23156.0  23646.0  24009.0  24396.0
#                Industria           27198.0  27708.0  28097.0  28074.0
#                Construcción        22163.0  22608.0  22971.0  22789.0
#                Servicios           22440.0  22944.0  23326.0  23845.0
# ...                                    ...      ...      ...      ...
# Rioja, La      NaN                     NaN      NaN      NaN      NaN
#                Todos los sectores  21999.0  22234.0  22641.0  22877.0
#                Industria           24100.0  24930.0  25425.0  26007.0
#                Construcción       -22440.0 -22607.0 -24208.0 -22840.0
#                Servicios           21067.0  21095.0  21413.0  21649.0
#
#                                       2020     2021
# Localización   Sector
# Total Nacional NaN                     NaN      NaN
#                Todos los sectores  25166.0  25897.0
#                Industria           28375.0  29104.0
#                Construcción        23105.0  24137.0
#                Servicios           24731.0  25449.0
# ...                                    ...      ...
# Rioja, La      NaN                     NaN      NaN
#                Todos los sectores  23293.0  23717.0
#                Industria           25056.0  24984.0
#                Construcción       -23751.0 -24899.0
#                Servicios           22572.0  23123.0
#
# [90 rows x 14 columns]

# %%
df_salario_ccaa_sexo_y_sectoractividad.isnull().sum()
# Out:
# 2008    18
# 2009    18
# 2010    18
# 2011    18
# 2012    18
# 2013    18
# 2014    18
# 2015    18
# 2016    18
# 2017    18
# 2018    18
# 2019    18
# 2020    18
# 2021    18
# dtype: int64

# %%
df_salario_ccaa_sexo_y_sectoractividad.dropna(inplace=True)
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/1002680008.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_salario_ccaa_sexo_y_sectoractividad.dropna(inplace=True)

# %%
df_salario_ccaa_sexo_y_sectoractividad.isnull().sum()
# Out:
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    0
# 2019    0
# 2020    0
# 2021    0
# dtype: int64

# %%
# Multiplica por -1 todos los valores negativos en el DataFrame
df_salario_ccaa_sexo_y_sectoractividad = df_salario_ccaa_sexo_y_sectoractividad.applymap(lambda x: -x if isinstance(x, (int, float)) and x < 0 else x)

df_salario_ccaa_sexo_y_sectoractividad
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/379606760.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_salario_ccaa_sexo_y_sectoractividad = df_salario_ccaa_sexo_y_sectoractividad.applymap(lambda x: -x if isinstance(x, (int, float)) and x < 0 else x)
#                                       2008     2009     2010     2011  \
# Localización   Sector
# Total Nacional Todos los sectores  21883.0  22511.0  22790.0  22899.0
#                Industria           24036.0  24453.0  25377.0  25872.0
#                Construcción        20707.0  21775.0  21962.0  22541.0
#                Servicios           21557.0  22171.0  22332.0  22315.0
# Andalucía      Todos los sectores  20139.0  20906.0  20964.0  21351.0
# ...                                    ...      ...      ...      ...
# País Vasco     Servicios           24248.0  25324.0  25591.0  24953.0
# Rioja, La      Todos los sectores  20674.0  21180.0  21036.0  20997.0
#                Industria           21660.0  21512.0  21783.0  22563.0
#                Construcción        20506.0  22006.0  22762.0  23519.0
#                Servicios           20215.0  20887.0  20436.0  19995.0
#
#                                       2012     2013     2014     2015  \
# Localización   Sector
# Total Nacional Todos los sectores  22726.0  22698.0  22858.0  23106.0
#                Industria           26122.0  26639.0  26997.0  27104.0
#                Construcción        22686.0  22721.0  22608.0  22661.0
#                Servicios           22040.0  21920.0  22077.0  22367.0
# Andalucía      Todos los sectores  20892.0  20782.0  20840.0  21381.0
# ...                                    ...      ...      ...      ...
# País Vasco     Servicios           25128.0  25332.0  26380.0  26043.0
# Rioja, La      Todos los sectores  20346.0  20629.0  21954.0  21757.0
#                Industria           22721.0  22387.0  23792.0  23862.0
#                Construcción        22767.0  22506.0  22984.0  23416.0
#                Servicios           19126.0  19759.0  21116.0  20730.0
#
#                                       2016     2017     2018     2019  \
# Localización   Sector
# Total Nacional Todos los sectores  23156.0  23646.0  24009.0  24396.0
#                Industria           27198.0  27708.0  28097.0  28074.0
#                Construcción        22163.0  22608.0  22971.0  22789.0
#                Servicios           22440.0  22944.0  23326.0  23845.0
# Andalucía      Todos los sectores  21268.0  21404.0  21806.0  22061.0
# ...                                    ...      ...      ...      ...
# País Vasco     Servicios           25765.0  26667.0  27010.0  28234.0
# Rioja, La      Todos los sectores  21999.0  22234.0  22641.0  22877.0
#                Industria           24100.0  24930.0  25425.0  26007.0
#                Construcción        22440.0  22607.0  24208.0  22840.0
#                Servicios           21067.0  21095.0  21413.0  21649.0
#
#                                       2020     2021
# Localización   Sector
# Total Nacional Todos los sectores  25166.0  25897.0
#                Industria           28375.0  29104.0
#                Construcción        23105.0  24137.0
#                Servicios           24731.0  25449.0
# Andalucía      Todos los sectores  22324.0  23155.0
# ...                                    ...      ...
# País Vasco     Servicios           29137.0  29995.0
# Rioja, La      Todos los sectores  23293.0  23717.0
#                Industria           25056.0  24984.0
#                Construcción        23751.0  24899.0
#                Servicios           22572.0  23123.0
#
# [72 rows x 14 columns]

# %%
df_salario_ccaa_sexo_y_sectoractividad.to_excel("df_salario_ccaa_sexo_y_sectoractividad.xlsx")

# %% [markdown]
# ## Salario medio Nacional Sexo y Edad

# %%
# Lectura de los datos inicial
df_salario_nacional_sexo_y_edad = pd.read_excel("databases/salarios/salario_nacional_sexo_y_edad/28189.xlsx", skiprows=7)
df_salario_nacional_sexo_y_edad
# Out:
# /opt/anaconda3/envs/first_project_ironhack/lib/python3.11/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#
# 15  23679.0  25913.0  27076.0  28273.0
# 16  26851.0  27557.0  28314.0  28891.0
# 17  18518.0  18088.0  18639.0  18381.0
# 18  16374.0  17067.0  17468.0  18221.0

# %%
# Comprobar si hay nulos
df_salario_nacional_sexo_y_seccionactividad.isnull().sum()
# Out:
# Sección de actividad    0
# 2008                    0
# 2009                    0
# 2010                    0
# 2011                    0
# 2012                    0
# 2013                    0
# 2014                    0
# 2015                    0
# 2016                    0
# 2017                    0
# 2018                    0
# 2019                    0
# 2020                    0
# 2021                    0
# dtype: int64

# %%
# Multiplica por -1 todos los valores negativos en el DataFrame
df_salario_nacional_sexo_y_seccionactividad = df_salario_nacional_sexo_y_seccionactividad.applymap(lambda x: -x if isinstance(x, (int, float)) and x < 0 else x)

df_salario_nacional_sexo_y_seccionactividad
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/2350257449.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_salario_nacional_sexo_y_seccionactividad = df_salario_nacional_sexo_y_seccionactividad.applymap(lambda x: -x if isinstance(x, (int, float)) and x < 0 else x)
#                                  Sección de actividad     2008     2009  \
# 0                             B_S Todas las secciones  21883.0  22511.0
# 1                            B Industrias extractivas  26647.0  27051.0
# 2                           C Industria manufacturera  23616.0  23907.0
# 3   D Suministro de energía eléctrica, gas, vapor ...  48579.0  50537.0
# 4   E Suministro de agua, actividades de saneamien...  22590.0  23617.0
# 5                                      F Construcción  20707.0  21775.0
# 6   G Comercio al por mayor y al por menor; repara...  18546.0  19499.0
# 7                       H Transporte y almacenamiento  21824.0  22197.0
# 8                                        I Hostelería  13957.0  13997.0
# 9                      J Información y comunicaciones  30628.0  31552.0
# 10             K Actividades financieras y de seguros  41619.0  41863.0
# 11                        L Actividades inmobiliarias  19534.0  19771.0
# 12  M Actividades profesionales, científicas y téc...  24734.0  25517.0
# 13  N Actividades administrativas y servicios auxi...  15818.0  15855.0
# 14  O Administración Pública y defensa; Seguridad ...  26928.0  27591.0
# 15                                        P Educación  20883.0  21703.0
# 16   Q Actividades sanitarias y de servicios sociales  24838.0  25623.0
# 17  R Actividades artísticas, recreativas y de ent...  16763.0  16858.0
# 18                                  S Otros servicios  15412.0  15869.0
#
#        2010     2011     2012     2013     2014     2015     2016     2017  \
# 0   22790.0  22899.0  22726.0  22698.0  22858.0  23106.0  23156.0  23646.0
# 1   28373.0  29223.0  30237.0  31390.0  32971.0  32494.0  32401.0  32556.0
# 2   24864.0  25308.0  25510.0  26042.0  26477.0  26544.0  26698.0  27214.0
# 3   48803.0  50371.0  52325.0  52828.0  51035.0  51920.0  50992.0  52015.0
# 4   24972.0  25570.0  25189.0  25291.0  25959.0  26340.0  26320.0  26937.0
# 5   21962.0  22541.0  22686.0  22721.0  22608.0  22661.0  22163.0  22608.0
# 6   19008.0  19445.0  19474.0  19069.0  19772.0  19651.0  19781.0  20609.0
# 7   22991.0  23347.0  23454.0  23525.0  23605.0  23938.0  23611.0  24080.0
# 8   14630.0  14235.0  13867.0  13851.0  13636.0  13977.0  14125.0  14540.0
# D Suministro de energía eléctrica, gas, vapor y...  52015.0  51237.0  52163.0
# E Suministro de agua, actividades de saneamient...  26937.0  27290.0  27486.0
# F Construcción                                      22608.0  22971.0  22789.0
# G Comercio al por mayor y al por menor; reparac...  20609.0  21006.0  21121.0
# H Transporte y almacenamiento                       24080.0  24654.0  24369.0
# I Hostelería                                        14540.0  14345.0  14562.0
# J Información y comunicaciones                      33664.0  33118.0  34641.0
# K Actividades financieras y de seguros              43774.0  45035.0  44303.0
# L Actividades inmobiliarias                         21299.0  21249.0  23333.0
# M Actividades profesionales, científicas y técn...  27450.0  28058.0  28150.0
# N Actividades administrativas y servicios auxil...  16520.0  17177.0  17108.0
# O Administración Pública y defensa; Seguridad S...  29015.0  29824.0  31091.0
# P Educación                                         23560.0  23679.0  25913.0
# Q Actividades sanitarias y de servicios sociales    26076.0  26851.0  27557.0
# R Actividades artísticas, recreativas y de entr...  17703.0  18518.0  18088.0
# S Otros servicios                                   16203.0  16374.0  17067.0
#
#                                                        2020     2021
# Sección de actividad
# B_S Todas las secciones                             25166.0  25897.0
# B Industrias extractivas                            34425.0  34866.0
# C Industria manufacturera                           27876.0  28586.0
# D Suministro de energía eléctrica, gas, vapor y...  53776.0  52986.0
# E Suministro de agua, actividades de saneamient...  27854.0  29278.0
# F Construcción                                      23105.0  24137.0
# G Comercio al por mayor y al por menor; reparac...  21393.0  22215.0
# H Transporte y almacenamiento                       25033.0  25545.0
# I Hostelería                                        14137.0  14633.0
# J Información y comunicaciones                      35664.0  36630.0
# K Actividades financieras y de seguros              45922.0  46122.0
# L Actividades inmobiliarias                         23355.0  24835.0
# M Actividades profesionales, científicas y técn...  28918.0  29927.0
# N Actividades administrativas y servicios auxil...  17809.0  18119.0
# O Administración Pública y defensa; Seguridad S...  32582.0  34010.0
# P Educación                                         27076.0  28273.0
# Q Actividades sanitarias y de servicios sociales    28314.0  28891.0
# R Actividades artísticas, recreativas y de entr...  18639.0  18381.0
# S Otros servicios                                   17468.0  18221.0

# %%
df_salario_nacional_sexo_y_seccionactividad.to_excel("df_salario_nacional_sexo_y_seccionactividad_clean.xlsx")

# %% [markdown]
# ## Gráficas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Gráficas Todas las edades por CCAA progresiva desde 2008 al 2021

# Filtrar el DataFrame para incluir solo las filas donde el rango de edad es "Todas las edades" y excluir "Total Nacional"
df_todas_edades = df_salario_ccaa_sexo_y_edad.xs('Todas las edades', level='Rango de edad').reset_index()

# Excluir "Total Nacional"
df_todas_edades = df_todas_edades[df_todas_edades['Localización'] != 'Total Nacional']

# Convertir el DataFrame a formato largo para usarlo con seaborn
df_long = df_todas_edades.melt(id_vars=["Localización"], 
                               var_name="Año", 
                               value_name="Salario")

# Crear la gráfica de líneas
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_long, x="Año", y="Salario", hue="Localización", marker="o")

# Configuramos los títulos y etiquetas
plt.title("Progresión de Salarios en el Rango 'Todas las edades' (2008-2021)", fontsize=14)
plt.xlabel("Año", fontsize=12)
plt.ylabel("Salario (€)", fontsize=12)
plt.xticks(rotation=45)
plt.legend(title="Comunidad Autónoma", bbox_to_anchor=(1.05, 1), loc='upper left')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

# %%
# Filtrar el DataFrame para incluir solo las filas donde el rango de edad es "Todas las edades" y excluir "Total Nacional"
df_todas_edades = df_salario_ccaa_sexo_y_edad.xs('Todas las edades', level='Rango de edad').reset_index()

# Excluir "Total Nacional"
df_todas_edades = df_todas_edades[df_todas_edades['Localización'] != 'Total Nacional']

# Crear una nueva columna con la media de los salarios desde 2008 a 2021 para cada CCAA
df_todas_edades['Media Salarios'] = df_todas_edades.iloc[:, 2:].mean(axis=1)

# Crear un gráfico de barras con las medias de salarios para cada CCAA
plt.figure(figsize=(10, 6))
sns.barplot(data=df_todas_edades, x="Localización", y="Media Salarios", palette="viridis")

# Configuramos los títulos y etiquetas
plt.title("Media de Salarios (2008-2021) por CCAA en el Rango 'Todas las edades'", fontsize=14)
plt.xlabel("Comunidad Autónoma", fontsize=12)
plt.ylabel("Media de Salario (€)", fontsize=12)
plt.xticks(rotation=90)

# Mostrar la gráfica
plt.tight_layout()
plt.show()
"""La Com.Madrid es la que tiene mayores salarios de todo el país. MENTIRA, es el País Vasco"""
# Out:
# /var/folders/ft/qxd3zsb519bf70l9x9qmkywm0000gn/T/ipykernel_21863/3073434500.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_todas_edades, x="Localización", y="Media Salarios", palette="viridis")

# %%
# Filtrar el DataFrame para incluir solo las filas donde el rango de edad es "Todas las edades" y excluir "Total Nacional"
df_todas_edades = df_salario_ccaa_sexo_y_edad.xs('Todas las edades', level='Rango de edad').reset_index()
df_todas_edades = df_todas_edades[df_todas_edades['Localización'] != 'Total Nacional']

# Calcular la diferencia salarial interanual (variación interanual)
df_diferencia_salarial = df_todas_edades.iloc[:, 2:].diff(axis=1)

# Calcular la media de la diferencia salarial interanual para cada CCAA
df_todas_edades['Media Diferencia Salarial'] = df_diferencia_salarial.mean(axis=1)

# Crear un gráfico de barras con la media de la diferencia salarial para cada CCAA
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=df_todas_edades, x="Localización", y="Media Diferencia Salarial", hue="Localización", palette="coolwarm", dodge=False, legend=False)

# Configuramos los títulos y etiquetas
plt.title("Subida salarial anual (2008-2021) por CCAA", fontsize=14)
plt.xlabel("Comunidad Autónoma", fontsize=12)
plt.ylabel("Incremento salarial anual (€)", fontsize=12)
plt.xticks(rotation=90)

# Agregar los valores exactos encima de cada barra
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Mostrar la gráfica
plt.tight_layout()
plt.show()

"""Entre 2008 y 2021 la subida salarial andaluza ha sido la mitad respecto a la CCAA con mayor incremento. VERDAD"""
# Out:
# 'Entre 2008 y 2021 la subida salarial andaluz ha sido la mitad respecto a la CCAA con mayor incremento.'

# %%
# Filtrar el DataFrame para incluir solo las filas donde el rango de edad es "Todas las edades" y excluir "Total Nacional"
df_todas_edades = df_salario_ccaa_sexo_y_edad.xs('Todas las edades', level='Rango de edad').reset_index()
df_todas_edades = df_todas_edades[df_todas_edades['Localización'] != 'Total Nacional']

# Filtrar los años pre-COVID (2011-2019) y post-COVID (2020-2021)
df_precovid = df_todas_edades.loc[:, "2011":"2019"]
df_postcovid = df_todas_edades.loc[:, "2020":"2021"]

# Calcular la diferencia salarial interanual (variación interanual) para ambos períodos
diferencias_precovid = df_precovid.diff(axis=1)
diferencias_postcovid = df_postcovid.diff(axis=1)

# Calcular la media de las diferencias interanuales para cada período
df_todas_edades['Media Diferencia Precovid'] = diferencias_precovid.mean(axis=1)
df_todas_edades['Media Diferencia Postcovid'] = diferencias_postcovid.mean(axis=1)

# Preparar el DataFrame para el gráfico de barras
df_bar = df_todas_edades.melt(id_vars=['Localización'], 
                              value_vars=['Media Diferencia Precovid', 'Media Diferencia Postcovid'], 
                              var_name='Periodo', 
                              value_name='Media Diferencia Salarial')

# Crear un gráfico de barras con las medias de la diferencia salarial interanual para cada CCAA en ambos períodos
plt.figure(figsize=(12, 6))
sns.barplot(data=df_bar, x="Localización", y="Media Diferencia Salarial", hue="Periodo", palette="Set2")

# Configuramos los títulos y etiquetas
plt.title("Incremento salarial anual Pre-COVID (2011-2019) y Post-COVID (2020-2021)", fontsize=14)
plt.xlabel("Comunidad Autónoma", fontsize=12)
plt.ylabel("Incremento salarial anual (€)", fontsize=12)
plt.xticks(rotation=90)

# Mostrar la gráfica
plt.tight_layout()
plt.show()
""" HIPÓTESIS. Es positivo que los salarios siempre crezcan. MENTIRA (Los datos sin contexto no sirven de nada.)"""

# %%
# Filtrar el DataFrame para incluir solo las filas donde el rango de edad es "Todas las edades" y excluir "Total Nacional"
df_todas_edades = df_salario_ccaa_sexo_y_edad.xs('Todas las edades', level='Rango de edad').reset_index()
df_todas_edades = df_todas_edades[df_todas_edades['Localización'] != 'Total Nacional']

# Calcular la diferencia salarial entre 2018 y 2019 (pre-COVID) y entre 2020 y 2021 (post-COVID)
df_todas_edades['Diferencia Precovid'] = df_todas_edades['2019'] - df_todas_edades['2018']
df_todas_edades['Diferencia Postcovid'] = df_todas_edades['2021'] - df_todas_edades['2020']

# Preparar el DataFrame para el gráfico de barras
df_bar = df_todas_edades.melt(id_vars=['Localización'], 
                              value_vars=['Diferencia Precovid', 'Diferencia Postcovid'], 
                              var_name='Periodo', 
                              value_name='Diferencia Salarial')

# Crear un gráfico de barras con las diferencias salariales entre ambos períodos para cada CCAA
plt.figure(figsize=(12, 6))
sns.barplot(data=df_bar, x="Localización", y="Diferencia Salarial", hue="Periodo", palette="Set2")

# Configuramos los títulos y etiquetas
plt.title("Diferencia Salarial Interanual Pre-COVID (2018-2019) y Post-COVID (2020-2021)", fontsize=14)
plt.xlabel("Comunidad Autónoma", fontsize=12)
plt.ylabel("Diferencia Salarial (€)", fontsize=12)
plt.xticks(rotation=90)

# Mostrar la gráfica
plt.tight_layout()
plt.show()
""" HIPÓTESIS. Es positivo que los salarios siempre crezcan. MENTIRA (Los datos sin contexto no sirven de nada.)"""
